# %%
pip install textblob
# Out:
# ...
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/624.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/624.3 kB ? eta -:--:--
#    ------------------------------- ------ 524.3/624.3 kB 778.6 kB/s eta 0:00:01
#    ---------------------------------------- 624.3/624.3 kB 515.8 kB/s  0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from textblob import TextBlob

text = "He has refused his Assent to Laws, the most wholesome and necessary for the."

analysis = TextBlob(text)

print("Polarity:", analysis.sentiment.polarity)

if analysis.sentiment.polarity > 0:
    print("Sentiment: Positive")
elif analysis.sentiment.polarity < 0:
    print("Sentiment: Negative")
else:
    print("Sentiment: Neutral")
# Out:
# Polarity: 0.25
# Sentiment: Positive

# %%
labels = ["positive", "negative", "neutral"]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(texts)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# 1. Dataset (simple example)
texts = [
    "I love this product",
    "This is amazing",
    "I hate this",
    "This is terrible",
    "It is okay",
    "Not bad",
    "Very good",
    "Worst experience"
]

labels = [
    "positive",
    "positive",
    "negative",
    "negative",
    "neutral",
    "neutral",
    "positive",
    "negative"
]

# 2. Convert text → numbers
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(texts)

# 3. Split data
X_train, X_test, y_train, y_test = train_test_split(
    X, labels, test_size=0.2, random_state=42
)

# 4. Train model
model = MultinomialNB()
model.fit(X_train, y_train)

# 5. Predict
predictions = model.predict(X_test)

# 6. Accuracy
print("Accuracy:", accuracy_score(y_test, predictions))

# 7. Test new input
new_text = ["I really love this chatbot"]
X_new = vectorizer.transform(new_text)
print("Prediction:", model.predict(X_new))
# Out:
# Accuracy: 0.0
# Prediction: ['negative']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# 1. Dataset (simple example)
texts = [
    "I love this product",
    "This is amazing",
    "I hate this",
    "This is terrible",
    "It is okay",
    "Not bad",
    "Very good",
    "Worst experience"
]

labels = [
    "positive",
    "positive",
    "negative",
    "negative",
    "neutral",
    "neutral",
    "positive",
    "negative"
]

# 2. Convert text → numbers
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(texts)

# 3. Split data
X_train, X_test, y_train, y_test = train_test_split(
    X, labels, test_size=0.2, random_state=42
)

# 4. Train model
model = MultinomialNB()
model.fit(X_train, y_train)

# 5. Predict
predictions = model.predict(X_test)

# 6. Accuracy
print("Accuracy:", accuracy_score(y_test, predictions))

# 7. Test new input
new_text = ["I really love this chatbot"]
X_new = vectorizer.transform(new_text)'two'0
print("Prediction:", model.predict(X_new))
