# %%
import pandas as pd
import random

careers = {
    "Software Engineer": [
        "I like coding",
        "I enjoy programming",
        "I want IT job",
        "I love computers",
        "I am studying B.Tech",
        "I like python",
        "I enjoy web development",
        "I want software job",
        "I like app development",
        "I love technology"
    ],
    
    "Data Scientist": [
        "I love data analysis",
        "I enjoy statistics",
        "I like machine learning",
        "I want analytics job",
        "I enjoy working with data",
        "I like AI",
        "I love numbers",
        "I want data career",
        "I enjoy python for data",
        "I like predictive modeling"
    ],
    
    "Mechanical Engineer": [
        "I like machines",
        "I love engines",
        "I enjoy automobile field",
        "I want core engineering job",
        "I like robotics",
        "I enjoy manufacturing",
        "I like industrial work",
        "I want mechanical career",
        "I enjoy production industry",
        "I like machinery"
    ],
    
    "Civil Engineer": [
        "I like construction",
        "I love buildings",
        "I enjoy designing bridges",
        "I want civil job",
        "I like infrastructure",
        "I enjoy site work",
        "I want government engineering job",
        "I like roads and buildings",
        "I enjoy structural design",
        "I want construction career"
    ],
    
    "Doctor": [
        "I like biology",
        "I want to become doctor",
        "I love medical field",
        "I enjoy helping patients",
        "I want healthcare job",
        "I like anatomy",
        "I want hospital career",
        "I enjoy medicine",
        "I want MBBS",
        "I like human body science"
    ],
    
    "Lawyer": [
        "I like law",
        "I enjoy legal studies",
        "I want judiciary career",
        "I like arguing",
        "I want advocate job",
        "I enjoy debates",
        "I want court practice",
        "I like criminal law",
        "I want legal profession",
        "I enjoy law field"
    ],
    
    "Chartered Accountant": [
        "I like accounting",
        "I enjoy finance",
        "I want CA career",
        "I like taxation",
        "I enjoy auditing",
        "I want finance job",
        "I like commerce",
        "I want accounting career",
        "I enjoy balance sheets",
        "I like business finance"
    ],
    
    "Business Management": [
        "I want MBA",
        "I like management",
        "I enjoy leadership",
        "I want corporate career",
        "I like entrepreneurship",
        "I want business job",
        "I enjoy marketing",
        "I like company management",
        "I want CEO role",
        "I enjoy administration"
    ],
    
    "Graphic Designer": [
        "I like drawing",
        "I love creativity",
        "I enjoy design",
        "I want creative job",
        "I like photoshop",
        "I enjoy animation",
        "I want designer career",
        "I like digital art",
        "I enjoy UI UX",
        "I want graphic design job"
    ],
    
    "Teacher": [
        "I like teaching",
        "I enjoy explaining",
        "I want professor job",
        "I like education field",
        "I want government teacher job",
        "I enjoy academic career",
        "I like school environment",
        "I want lecturer position",
        "I enjoy guiding students",
        "I like training others"
    ]
}

rows = []

for career, sentences in careers.items():
    for i in range(120):   # 120 variations per career
        sentence = random.choice(sentences)
        variation = sentence + " " + random.choice([
            "as my future",
            "for my career",
            "after graduation",
            "in future",
            "as profession",
            "as my goal",
            "for my life",
            "after studies"
        ])
        rows.append([variation, career])

df = pd.DataFrame(rows, columns=["text", "career"])
df.to_csv("career_dataset.csv", index=False)

print("Dataset created successfully!")
print("Total rows:", len(df))
# Out:
# Dataset created successfully!
# Total rows: 1200
