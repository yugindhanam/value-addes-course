# %%
text="the agent;s phone number is 408-555-1234. call soon!"

# %%
'phone' in text
# Out:
# True

# %% [raw]
# import re

# %%
pattern='phone'

# %%
import re
match= re.search(pattern,text)

# %%
match
# Out:
# <re.Match object; span=(12, 17), match='phone'>

# %%
match.span()
# Out:
# (12, 17)

# %%
text="my phone is a new phone phone phone"

# %%
matches=re.findall("phone",text)

# %%
matches
# Out:
# ['phone', 'phone', 'phone', 'phone']

# %%
for match in re.finditer("phone",text):
    print(match.span())
# Out:
# (3, 8)
# (18, 23)
# (24, 29)
# (30, 35)

# %%
text="my telephone number is 409-555-1234"

# %%
phone=re.search(r'\d\d\d-\d\d\d-\d\d\d\d',text)

# %%
phone.group()
# Out:
# '409-555-1234'

# %%
re.search(r'\d{3}-\d{3}-\d{4}',text)
# Out:
# <re.Match object; span=(23, 35), match='409-555-1234'>

# %%
phone_pattern=re.compile(r'(\d{3})-(\d{3})-(\d{4})')

# %%
results=re.search(phone_pattern,text)

# %%
results.group()
# Out:
# '409-555-1234'

# %%
results.group(1)
# Out:
# '409'

# %%
re.search(r"man|woman","this man was here.")
# Out:
# <re.Match object; span=(5, 8), match='man'>

# %%
re.findall(r"man|woman","this woman man was here.")
# Out:
# ['woman', 'man']

# %%
re.findall(r".at","the cat in the hat sat here.")
# Out:
# ['cat', 'hat', 'sat']

# %%
re.findall(r"...at","the bat went splat")
# Out:
# ['e bat', 'splat']

# %%
re.findall(r'\S+at',"the bat went to splat")
# Out:
# ['bat', 'splat']

# %%
#ends with a number
re.findall(r'\d$','this ends with a number 2')
# Out:
# ['2']

# %%
#ends with a number
re.findall(r'^\d','63 is the lineliest number')
# Out:
# ['6']

# %%
phrase="threre are 3 numbers 34 inside 5 this sentence."

# %%
re.findall(r'[^\d]+',phrase) #removing the number
# Out:
# ['threre are ', ' numbers ', ' inside ', ' this sentence.']

# %%
test_phrase="thsi is a string! but it has punctuation. how can we remove it?"

# %%
re.findall('[^!.?]+',test_phrase)
# Out:
# ['thsi is a string', ' but it has punctuation']

# %%
clean=' '.join(re.findall('[^!.?]+',test_phrase))

# %%
clean
# Out:
# 'thsi is a string  but it has punctuation'

# %%
text='only find the hypen-word in this sentence.but you dono know how long-ish they are'

# %%
re.findall(r'[\w]+-[\w]+',text)
# Out:
# ['hypen-word', 'long-ish']

# %%
text='hello,would you like some catfish?'
texttwo="hello, would you like to take a catnap?"
textthree="hello, have you seen this caterpillar?"

# %%
re.search(r'cat(fish|nap|claw)',text)
# Out:
# <re.Match object; span=(26, 33), match='catfish'>

# %%
re.search(r'cat(fish|nap|claw)',texttwo)
# Out:
# <re.Match object; span=(32, 38), match='catnap'>

# %%
re.search(r'cat(fish|nap|claw)',textthree)
