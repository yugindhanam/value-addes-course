# %%
# !pip install nltk
import nltk
from nltk.stem.porter import*
# Out:
# Requirement already satisfied: nltk in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (3.9.2)
# Requirement already satisfied: click in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk) (2026.2.19)
# Requirement already satisfied: tqdm in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from click->nltk) (0.4.6)

# %%
# !pip install nltk
import nltk
from nltk.stem.porter import*
# Out:
# Collecting nltk
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: click in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk) (8.3.1)
# Collecting joblib (from nltk)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2026.2.19-cp311-cp311-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: tqdm in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in .\AppData\Local\Programs\Python\Python311\Lib\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 13.3 MB/s  0:00:00
# Downloading regex-2026.2.19-cp311-cp311-win_amd64.whl (277 kB)
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Installing collected packages: regex, joblib, nltk
#
#    ---------------------------------------- 0/3 [regex]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    ---------------------------------------- 3/3 [nltk]
#
# Successfully installed joblib-1.5.3 nltk-3.9.2 regex-2026.2.19

# %%
#porterstemmer
p_stemmer=PorterStemmer()

# %%
words=['run','runner','running','ran','runs','easily','fairly']

# %%
for word in words:
    print(word+'-->'+p_stemmer.stem(word))
# Out:
# run-->run
# runner-->runner
# running-->run
# ran-->ran
# runs-->run
# easily-->easili
# fairly-->fairli

# %%
from nltk.stem.snowball import SnowballStemmer

s_stemmer = SnowballStemmer(language='english') 
print('porter2 stemmer:')
for word in words:
    print(word+'---->'+s_stemmer.stem(word))
# Out:
# porter2 stemmer:
# run---->run
# runner---->runner
# running---->run
# ran---->ran
# runs---->run
# easily---->easili
# fairly---->fair

# %%
words=['run','runner','running','ran','runs','easily','fairly']
#words=['generous','generation','generously','generate']

# %%
for word in words:
    print(word+'-->'+p_stemmer.stem(word))
# Out:
# run-->run
# runner-->runner
# running-->run
# ran-->ran
# runs-->run
# easily-->easili
# fairly-->fairli

# %%
phrase='I am metting him tomorrow at the meeting'
for word in phrase.split():
    print(word+'---->'+p_stemmer.stem(word))
# Out:
# I---->i
# am---->am
# metting---->met
# him---->him
# tomorrow---->tomorrow
# at---->at
# the---->the
# meeting---->meet

# %%
phrase='I am metting him tomorrow at the meeting'
for word in phrase.split():
    print(word+'---->'+s_stemmer.stem(word))
# Out:
# I---->i
# am---->am
# metting---->met
# him---->him
# tomorrow---->tomorrow
# at---->at
# the---->the
# meeting---->meet

# %%
phrase='I am going to eat chicken in this afternoon and dinner chapathi '
for word in phrase.split():
    print(word+'---->'+p_stemmer.stem(word))
# Out:
# I---->i
# am---->am
# going---->go
# to---->to
# eat---->eat
# chicken---->chicken
# in---->in
# this---->thi
# afternoon---->afternoon
# and---->and
# dinner---->dinner
# chapathi---->chapathi
