# %%
import spacy
nlp=spacy.load('en_core_web_sm')

# %%
mystring='"we\'re moving to L.A.!"'
print(mystring)
# Out:
# "we're moving to L.A.!"

# %%
#create doc object and explore token
doc=nlp(mystring)
for token in doc:
    print(token.text,end='|')
# Out:
# "|we|'re|moving|to|L.A.|!|"|

# %%
doc3=nlp(u'A 5km NYC cab rides costss $10.30')
for t in doc3:
    print(t)
# Out:
# A
# 5
# km
# NYC
# cab
# rides
# costss
# $
# 10.30

# %%
doc4=nlp(u"let's visit st. louis in the U.S. next year.")

for t in doc4:
    print(t)
# Out:
# let
# 's
# visit
# st
# .
# louis
# in
# the
# U.S.
# next
# year
# .

# %%
len(doc)
# Out:
# 8

# %%
len(doc.vocab)
# Out:
# 784

# %%
doc5=nlp(u'It is better to give than to receive.')
doc5[2]
# Out:
# better

# %%
doc5[2:5]
# Out:
# better to give

# %%
doc5[-4:]
# Out:
# than to receive.

# %%
doc6=nlp(u'my dinner was horrible.')
doc7=nlp(u'you dinner was delicious')

# %%
doc6[3]=doc7[3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 doc6[3]=doc7[3]
#
# TypeError: 'spacy.tokens.doc.Doc' object does not support item assignment

# %%
#name entities
doc8=nlp("Apply to build a hong kong factory for $6 million")
for token in doc8:
    print(token.text,end='|')

print('\n----')

for ent in doc8.ents:
    print(ent.text+'-'+ent.label_+'-'+str(spacy.explain(ent.label_)))
# Out:
# Apply|to|build|a|hong|kong|factory|for|$|6|million|
# ----
# hong kong-GPE-Countries, cities, states
# $6 million-MONEY-Monetary values, including unit

# %%
len(doc8.ents)
# Out:
# 2

# %%
doc9=nlp(u"autnomous cars shift insurance liability toward manufacturers.")
for chunk in doc9.noun_chunks:
    print(chunk.text)
# Out:
# autnomous cars
# insurance liability
# manufacturers

# %%
doc10=nlp(u"Red cars do not carry higher insurance rates.")
for chunk in doc10.noun_chunks:
    print(chunk.text)
# Out:
# Red cars
# higher insurance rates

# %%
doc11=nlp(u"he was one-eyed, on-horned, flying, purple people-eater.")
for chunk in doc11.noun_chunks:
    print(chunk.text)
# Out:
# he
# one-eyed, on-horned, flying, purple people-eater

# %%
from spacy import displacy

doc=nlp(u'Apple is going to build a U.K. factory for $6 million.')
displacy.render(doc,style='dep',jupyter=True,options={'distance':110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5dfb814cf19a407ebe34542dbdd052a5-0" class="displacy" width="1370" height="357.0" direction="ltr" style="max-width: none; height: 357.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
# ...

# %%
doc=nlp(u'over the last quarter appple sold nearly 20 thousand ipods for a profit of $6 million.')
displacy.render(doc,style='ent',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  appple sold
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly 20 thousand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ipods for a profit of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $6 million
# ...
