# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np 
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\Home\smsspamcollection.tsv',sep='\t')
df.head()
# Out:
#   label                                            message  length  punct
# 0   ham  Go until jurong point, crazy.. Available only ...     111      9
# 1   ham                      Ok lar... Joking wif u oni...      29      6
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...     155      6
# 3   ham  U dun say so early hor... U c already then say...      49      6
# 4   ham  Nah I don't think he goes to usf, he lives aro...      61      2

# %%
len(df)
# Out:
# 5572

# %%
df.isnull().sum()
# Out:
# label      0
# message    0
# length     0
# punct      0
# dtype: int64

# %%
df['label'].unique()
# Out:
# <StringArray>
# ['ham', 'spam']
# Length: 2, dtype: str

# %%
df['label'].value_counts()
# Out:
# label
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
df['length'].describe()
# Out:
# count    5572.000000
# mean       80.489950
# std        59.942907
# min         2.000000
# 25%        36.000000
# 50%        62.000000
# 75%       122.000000
# max       910.000000
# Name: length, dtype: float64

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.xscale('log')
bins=1.15**(np.arange(0,50))
plt.hist(df[df['label']=='ham']['length'],bins=bins,alpha=0.8)
plt.hist(df[df['label']=='spam']['length'],bins=bins,alpha=0.8)
plt.legend(('ham','spam'))
plt.show()

# %%
df['punct'].describe()
# Out:
# count    5572.000000
# mean        4.177495
# std         4.623919
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         6.000000
# max       133.000000
# Name: punct, dtype: float64

# %%
x=df[['length','punct']]
y=df['label']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)
print('traiining data shape:',x_train.shape)
print('tresting data shape:',x_test.shape)
# Out:
# traiining data shape: (3733, 2)
# tresting data shape: (1839, 2)

# %%
#train a logistic regression classifier
#dependent variable is x and independent as y
from sklearn.linear_model import LogisticRegression
lr_model=LogisticRegression(solver='lbfgs')
lr_model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn import metrics
#create a prediction set
predictions=lr_model.predict(x_test)
#print the confusion matrix
print(metrics.confusion_matrix(y_test,predictions))
# Out:
# [[1547   46]
#  [ 241    5]]

# %%
# you can make the confusion matrix less confusing by addding
df=pd.DataFrame(metrics.confusion_matrix(y_test,predictions),index=['ham','spam'],columns=['ham','spam'])
df
# Out:
#        ham  spam
# ham   1547    46
# spam   241     5

# %%
#print the classification report
print(metrics.classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.87      0.97      0.92      1593
#         spam       0.10      0.02      0.03       246
#
#     accuracy                           0.84      1839
#    macro avg       0.48      0.50      0.47      1839
# weighted avg       0.76      0.84      0.80      1839

# %%
#train the naive bayes classifier:

from sklearn.naive_bayes import MultinomialNB
nb_model=MultinomialNB()
nb_model.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
predictions=nb_model.predict(x_test)
print(metrics.confusion_matrix(y_test,predictions))
# Out:
# [[1583   10]
#  [ 246    0]]

# %%
print(metrics.classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.87      0.99      0.93      1593
#         spam       0.00      0.00      0.00       246
#
#     accuracy                           0.86      1839
#    macro avg       0.43      0.50      0.46      1839
# weighted avg       0.75      0.86      0.80      1839

# %%
#train a support vector machine (Svm) classifier
from sklearn.svm import SVC
svc_model=SVC(gamma='auto')
svc_model.fit(x_train,y_train)
# Out:
# SVC(gamma='auto')
