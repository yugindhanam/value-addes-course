# %%
import spacy
nlp=spacy.load('en_core_web_sm')

# %%
#from spacy basics:
doc=nlp(U'this is the first sentence. this is another sentence. this is the last sentence.')
for sent in doc.sents:
    print(sent)
# Out:
# this is the first sentence.
# this is another sentence.
# this is the last sentence.

# %%
print(doc[1])
# Out:
# is

# %%
sentences=list(doc.sents)
print(sentences[1])
# Out:
# this is another sentence.

# %%
doc_sents=[sent for sent in doc.sents]
doc_sents
# Out:
# [this is the first sentence.,
#  this is another sentence.,
#  this is the last sentence.]

# %%
print(doc_sents[1])
# Out:
# this is another sentence.

# %%
type(doc_sents[1])
# Out:
# spacy.tokens.span.Span

# %%
print(doc_sents[1].start,doc_sents[1].end)
# Out:
# 6 11

# %%
doc2=nlp(U'this is the first sentence. this is another sentence. this is the last sentence.')
for token in doc2:
    print(token.is_sent_end,' '+token.text)
# Out:
# False  this
# False  is
# False  the
# False  first
# False  sentence
# True  .
# False  this
# False  is
# False  another
# False  sentence
# True  .
# False  this
# False  is
# False  the
# False  last
# False  sentence
# True  .

# %%
#spacy default behaviour
doc=nlp(U'"Management is doing things right;leadership is doing the right thigs."-peter drucker')
for sent in doc.sents:
    print(sent)
    print('\n')
# Out:
# "Management is doing things right;leadership is doing the right thigs.
#
#
# "-peter drucker

# %%
doc
# Out:
# "Management is doing things right;leadership is doing the right thigs."-peter drucker

# %%
#(-) is used to remove the last word
doc[:-1]
# Out:
# "Management is doing things right;leadership is doing the right thigs."-peter

# %%
from spacy.language import Language
@Language.component("set_custom_boundaries")

#add a new rule to the pipeline
def set_custom_boundaries(doc):
    for token in doc[:-1]:
        if token.text==';':
            doc[token.i+1].is_sent_start=True
    return doc

# %%
nlp.add_pipe("set_custom_boundaries",before='parser')
print(nlp.pipe_names)
# Out:
# ['tok2vec', 'tagger', 'set_custom_boundaries', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
doc4=nlp(U'"Management is doing. things right; leadership is doing the right thigs."-peter drucker')
for sent in doc4.sents:
    print(sent)
# Out:
# "Management ding.; things right; leadership is doing the right thigs.
# "-peter drucker

# %%
doc4[4]
# Out:
# ;

# %%
doc4[4].is_sent_start=True
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 doc4[4].is_sent_start=True
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\spacy\tokens\token.pyx:535, in spacy.tokens.token.Token.is_sent_start.__set__()
#
# ValueError: [E043] Refusing to write to token.sent_start if its document is parsed, because this may cause inconsistent state.

# %%
nlp=spacy.load('en_core_web_sm')
mystring=u"this is a sentence. this is another.\n\nThis is a \n third sentence."
#spacy default behavior:

doc=nlp(mystring)
for sent in doc.sents:
    print([token.text for token in sent])
# Out:
# ['this', 'is', 'a', 'sentence', '.']
# ['this', 'is', 'another', '.', '\n\n']
# ['This', 'is', 'a', '\n ', 'third', 'sentence', '.']
