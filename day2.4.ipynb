# %%
import spacy
nlp=spacy.load('en_core_web_sm')

# %%
doc=nlp(u"the quick brown for jumper over the lazy dog's back.")
print(doc.text)
# Out:
# the quick brown for jumper over the lazy dog's back.

# %%
print(doc[4].text,doc[4].pos_,doc[4].tag_,spacy.explain(doc[4].tag_))
# Out:
# jumper PROPN NNP noun, proper singular

# %%
for token in doc:
    print(f"{token.text:{10}}{token.pos_:{8}}{token.tag_:{6}}{spacy.explain(token.tag_)}")
# Out:
# the       DET     DT    determiner
# quick     ADJ     JJ    adjective (English), other noun-modifier (Chinese)
# brown     NOUN    NN    noun, singular or mass
# for       ADP     IN    conjunction, subordinating or preposition
# jumper    NOUN    NN    noun, singular or mass
# over      ADP     IN    conjunction, subordinating or preposition
# the       DET     DT    determiner
# lazy      ADJ     JJ    adjective (English), other noun-modifier (Chinese)
# dog       NOUN    NN    noun, singular or mass
# 's        PART    POS   possessive ending
# back      NOUN    NN    noun, singular or mass
# .         PUNCT   .     punctuation mark, sentence closer

# %%
doc=nlp(u'I read books on NLP.')
r=doc[1]
print(f'{r.text:{10}}{r.pos_:{8}}{r.tag_:{6}}{spacy.explain(r.tag_)}')
# Out:
# read      VERB    VBP   verb, non-3rd person singular present

# %%
doc=nlp(u'I read book on NLP.')
r=doc[1]
print(f'{r.text:{10}}{r.pos_:{8}}{r.tag_:{6}}{spacy.explain(r.tag_)}')
# Out:
# read      VERB    VBP   verb, non-3rd person singular present

# %%
Dep_counts=doc.count_by(spacy.attrs.DEP)
for k,v in sorted(Dep_counts.items()):
    print(f'{k}.{doc.vocab[k].text:{4}}:{v}')
# Out:
# 416.dobj:1
# 429.nsubj:1
# 439.pobj:1
# 443.prep:1
# 445.punct:1
# 8206900633647566924.ROOT:1

# %%
from spacy import displacy

# %%
doc=nlp(u"the quick brown fox jumbed over the lazy dog's back")
for token in doc:
    print(f"{token.text:{10}}{token.pos_:{7}}{token.dep_:{7}}{spacy.explain(token.tag_)}")
# Out:
# the       DET    det    determiner
# quick     ADJ    amod   adjective (English), other noun-modifier (Chinese)
# brown     ADJ    amod   adjective (English), other noun-modifier (Chinese)
# fox       NOUN   nsubj  noun, singular or mass
# jumbed    VERB   ROOT   verb, past tense
# over      ADP    prep   conjunction, subordinating or preposition
# the       DET    det    determiner
# lazy      ADJ    amod   adjective (English), other noun-modifier (Chinese)
# dog       NOUN   pobj   noun, singular or mass
# 's        PART   case   possessive ending
# back      ADV    advmod adverb

# %%
displacy.render(doc,style='dep',jupyter=True,options={'distance':110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2574aa36c38a4735b0de17f06f23db3a-0" class="displacy" width="1260" height="357.0" direction="ltr" style="max-width: none; height: 357.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">quick</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">brown</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">fox</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">jumbed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">over</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">lazy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">dog</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">back</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">ADV</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2574aa36c38a4735b0de17f06f23db3a-0-0" stroke-width="2px" d="M70,222.0 C70,57.0 375.0,57.0 375.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2574aa36c38a4735b0de17f06f23db3a-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,224.0 L62,212.0 78,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2574aa36c38a4735b0de17f06f23db3a-0-1" stroke-width="2px" d="M180,222.0 C180,112.0 370.0,112.0 370.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2574aa36c38a4735b0de17f06f23db3a-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M180,224.0 L172,212.0 188,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2574aa36c38a4735b0de17f06f23db3a-0-2" stroke-width="2px" d="M290,222.0 C290,167.0 365.0,167.0 365.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2574aa36c38a4735b0de17f06f23db3a-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290,224.0 L282,212.0 298,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2574aa36c38a4735b0de17f06f23db3a-0-3" stroke-width="2px" d="M400,222.0 C400,167.0 475.0,167.0 475.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2574aa36c38a4735b0de17f06f23db3a-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400,224.0 L392,212.0 408,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2574aa36c38a4735b0de17f06f23db3a-0-4" stroke-width="2px" d="M510,222.0 C510,167.0 585.0,167.0 585.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2574aa36c38a4735b0de17f06f23db3a-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M585.0,224.0 L593.0,212.0 577.0,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2574aa36c38a4735b0de17f06f23db3a-0-5" stroke-width="2px" d="M730,222.0 C730,112.0 920.0,112.0 920.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2574aa36c38a4735b0de17f06f23db3a-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M730,224.0 L722,212.0 738,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2574aa36c38a4735b0de17f06f23db3a-0-6" stroke-width="2px" d="M840,222.0 C840,167.0 915.0,167.0 915.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2574aa36c38a4735b0de17f06f23db3a-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M840,224.0 L832,212.0 848,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2574aa36c38a4735b0de17f06f23db3a-0-7" stroke-width="2px" d="M620,222.0 C620,57.0 925.0,57.0 925.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2574aa36c38a4735b0de17f06f23db3a-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M925.0,224.0 L933.0,212.0 917.0,212.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2574aa36c38a4735b0de17f06f23db3a-0-8" stroke-width="2px" d="M950,222.0 C950,167.0 1025.0,167.0 1025.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2574aa36c38a47

# %%
#render is used inside the jupiter noteboon
#and server is used to print outside the jupyter notebook
doc2=nlp(u"thisis a sentence this is antoher possibly longer sesntence.")
spans=list(doc2.sents)
options={'distance':110,'compact':'False','color':'blue','bg':'#FF0000','font':'Times'}
displacy.render(doc2,style='dep',jupyter=True,options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d2fd0cfb1bae4532b4fd0a4b6dde120f-0" class="displacy" width="1040" height="302.0" direction="ltr" style="max-width: none; height: 302.0px; color: blue; background: #FF0000; font-family: Times; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">thisis</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">sentence</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">antoher</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">possibly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">longer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">sesntence.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d2fd0cfb1bae4532b4fd0a4b6dde120f-0-0" stroke-width="2px" d="M172,167.0 172,148.66666666666666 264.0,148.66666666666666 264.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d2fd0cfb1bae4532b4fd0a4b6dde120f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M172,169.0 L168,161.0 176,161.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d2fd0cfb1bae4532b4fd0a4b6dde120f-0-1" stroke-width="2px" d="M62,167.0 62,130.33333333333334 267.0,130.33333333333334 267.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d2fd0cfb1bae4532b4fd0a4b6dde120f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M267.0,169.0 L271.0,161.0 263.0,161.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d2fd0cfb1bae4532b4fd0a4b6dde120f-0-2" stroke-width="2px" d="M392,167.0 392,148.66666666666666 484.0,148.66666666666666 484.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d2fd0cfb1bae4532b4fd0a4b6dde120f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M392,169.0 L388,161.0 396,161.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d2fd0cfb1bae4532b4fd0a4b6dde120f-0-3" stroke-width="2px" d="M282,167.0 282,130.33333333333334 487.0,130.33333333333334 487.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d2fd0cfb1bae4532b4fd0a4b6dde120f-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">relcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M487.0,169.0 L491.0,161.0 483.0,161.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d2fd0cfb1bae4532b4fd0a4b6dde120f-0-4" stroke-width="2px" d="M502,167.0 502,148.66666666666666 594.0,148.66666666666666 594.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d2fd0cfb1bae4532b4fd0a4b6dde120f-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M594.0,169.0 L598.0,161.0 590.0,161.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d2fd0cfb1bae4532b4fd0a4b6dde120f-0-5" stroke-width="2px" d="M722,167.0 722,130.33333333333334 927.0,130.33333333333334 927.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d2fd0cfb1bae4532b4fd0a4b6dde120f-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M722,169.0 L718,161.0 726,161.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d2fd0cfb1bae4532b4fd0a4b6dde120f-0-6" stroke-width="2px" d="M832,167.0 832,148.66666666666666 924.0,148.66666666666666 924.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d2fd0cfb1bae4532b4fd0a4b6dde120f-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M832,169.0 L828,161.0 836,161.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d2fd0cfb1bae4532b4fd0a4b6dde120f-0-7" stroke-width="2px" d="M62,167.0 62,112.0 930.0,112.0 930.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d2fd0cfb1bae4532b4fd0a4b6dde120f-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M930.0,169.0 L934.0,161.0 926.0,161.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
def show_ents(doc):
    if doc.ents:
         for ent in doc.ents:
              print(ent.text+'-'+ent.label_+'-'+str(spacy.explain(ent.label_)))
    else:
        print('No named entities found.')

# %%
doc=nlp(U"may i go to washington, de next may to see the washington monuments?")
show_ents(doc)
# Out:
# washington-GPE-Countries, cities, states
# washington-GPE-Countries, cities, states

# %%
doc=nlp(u'can i please borrow 500 dolars from you to buy some microsoft stock?')
for ent in doc.ents:
    print(ent.text,ent.start,ent.end,ent.start_char,ent.end_char,ent.label_)
# Out:
# 500 4 5 20 23 CARDINAL

# %%
doc=nlp(U"tesla to build U.K. factory for $6 million")
show_ents(doc)
# Out:
# U.K.-GPE-Countries, cities, states
# $6 million-MONEY-Monetary values, including unit

# %%
doc=nlp(U"Tesla to build a U.K. facotry for $6million")
ORG=doc.vocab.strings[U'ORG']
new_ent=spacy.tokens.span.Span(doc,0,1,label=ORG)
doc.ents=list(doc.ents)+[new_ent]
show_ents(doc)
# Out:
# Tesla-ORG-Companies, agencies, institutions, etc.
# U.K.-GPE-Countries, cities, states
# 6million-MONEY-Monetary values, including unit

# %%
doc=nlp(U"Our company plans to introduce a new vaccum cleaner."U"if sucessfull, the vaccum cleaner willl ve our first product.")
show_ents(doc)
# Out:
# first-ORDINAL-"first", "second", etc.

# %%
from spacy.matcher import PhraseMatcher
matcher=PhraseMatcher(nlp.vocab)

# %%
doc=nlp(U"Our company plans to introduce a new vaccum cleaner "U"Iif successful, the vaccum cleaner wil be our first product.")
phrase_list=['vaccum cleaner','vaccum_cleaner']
phrase_patterns=[nlp(text) for text in phrase_list]
matcher.add('newProduct',None,*phrase_patterns)
matches=matcher(doc)
matches
# Out:
# [(4452177204818730156, 7, 9), (4452177204818730156, 13, 15)]

# %%
#spacy default behaviour
doc=nlp(U'"Management is doing things right;leadership is doing the right thigs."-peter drucker')
for sent in doc.sents:
    print(sent)
    print('\n')
# Out:
# "Management is doing things right;leadership is doing the right thigs.
#
#
# "-peter drucker

# %%
doc
# Out:
# "Management is doing things right;leadership is doing the right thigs."-peter drucker

# %%
#(-) is used to remove the last word
doc[:-1]
# Out:
# "Management is doing things right;leadership is doing the right thigs."-peter

# %%
from spacy.language import Language
@Language.component("set_custom_boundaries")

#add a new rule to the pipeline
def set_custom_boundaries(doc):
    for token in doc[:-1]:
        if token.text==';':
            doc[token.i+1].is_sent_start=True
    return doc

# %%
nlp.add_pipe("set_custom_boundaries",before='parser')
print(nlp.pipe_names)
# Out:
# ['tok2vec', 'tagger', 'set_custom_boundaries', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
doc4=nlp(U'"Management is doing things right; leadership is doing the right thigs."-peter drucker')
for sent in doc4.sents:
    print(sent)
# Out:
# "Management is doing things right;
# leadership is doing the right thigs.
# "-peter drucker
