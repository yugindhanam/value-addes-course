# %%
name="yugin"
print("my name is {var}.".format(var=name))
# Out:
# my name is yugin.

# %%
name="yugin"
course="advanced ai"

message=f"my name is {name} and i am learning {course}."
print(message)
# Out:
# my name is yugin and i am learning advanced ai.

# %%
name = "fred"
print(f"his name is {name!r}")
# Out:
# his name is 'fred'

# %%
d = {'a': 'yugin', 'b': 456}
print(f"address:{d['a']} main street")
# Out:
# address:yugin main street

# %%
library=[('author','topic','pages'),('twain','rafting',601),('feynman','phusics',95),('hamilton','mythology',144)]
for book in library:
    print(f'{book[0]:{13}} {book[1]:{13}} {book[2]:->{5}}')
# Out:
# author        topic         pages
# twain         rafting       --601
# feynman       phusics       ---95
# hamilton      mythology     --144

# %%
from datetime import datetime
today=datetime(year=9999,month=2,day=28)
print(f'{today:%B %d,%y}')
# Out:
# February 28,99

# %%
# %%writefile ZORO.txt
# hello this is a quick test file.
#     this is the second line of the file.
# Out:
# Overwriting ZORO.txt

# %%
my_file=open("zoro.txt")

# %%
my_file.read()
# Out:
# 'hello this is a quick test file.\n    this is the second line of the file.\n'

# %%
pwd
# Out:
# 'C:\\Users\\Home'

# %%
my_file.seek(0)
# Out:
# 0

# %%
my_file.seek(0)
my_file.readlines()
# Out:
# ['hello this is a quick test file.\n',
#  '    this is the second line of the file.\n']

# %%
my_file= open('zoro.txt','w+')

# %%
my_file.write("this is a new first line \n")
# Out:
# 26

# %%
my_file.seek(0)
my_file.read()
# Out:
# 'this is a new first line \n'

# %%
my_file.close()

# %%
#appending
my_file=open('zoro.txt','a+')
my_file.write('\nthis line is being appended to zoro.txt')
my_file.write('\n and another line here.')
# Out:
# 24

# %%
my_file.seek(0)
print(my_file.read())
# Out:
# this is a new first line
#
# this line is being appended to zoro.txt
#  and another line here.

# %%
with open('zoro.txt','r') as txt:
    first_line=txt.readlines()[0]
print(first_line)
# Out:
# this is a new first line

# %%
with open('zoro.txt','r') as txt:
    for line in txt:
        print(line,end=' ')
# Out:
# this is a new first line
#
#  this line is being appended to zoro.txt
#   and another line here.
