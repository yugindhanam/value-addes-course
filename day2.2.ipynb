# %%
#perform the standard import
import spacy
nlp=spacy.load('en_core_web_sm')

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'also', 'there', 'per', 'does', 'between', 'why', 'in', "'re", 'his', 'every', 'never', 'two', 'n’t', 'i', 'anyhow', 'except', 'she', '’ll', 'those', 'us', 'that', 'here', 'at', 'not', 'did', 'though', '‘d', 'always', 'seem', 'already', 'mostly', 'again', 'may', 'where', 'full', 'anyone', 'one', 'thereafter', 'show', 'former', 'within', 'somewhere', 'you', 'hers', 'mine', 'while', 'could', 'own', 'about', 'say', 'elsewhere', 'beside', 'alone', 'further', 'whither', 'take', 'empty', 'sometime', 'everyone', 'whoever', 'to', 'for', 'three', 'none', 'third', 'so', 'latter', 'whether', 'yourself', 'hereafter', 'wherever', 'seemed', 'most', 'some', 'ever', 'me', 'around', 'become', 'besides', 'towards', 'before', '‘ll', 'by', 'through', 'done', 'whenever', 'either', '’re', 'myself', 'because', '‘m', "'ve", 'this', 'least', 'upon', 'he', 'these', 'throughout', 'beforehand', 'first', 'go', 'thence', 'who', 'are', 'might', 'therefore', 'across', 'being', 'anyway', 'ourselves', 'back', 'n‘t', 'eleven', 'very', 'off', 'next', 'namely', 'until', 'hundred', 'along', 'on', 'nobody', 'her', 'nowhere', 'otherwise', 'call', 'please', 'when', 'only', 'much', 'nine', 'anywhere', 'twelve', 'six', 'seems', 'front', '‘re', '’m', 'get', 'our', 'we', "n't", 'an', 'keep', 'if', 'few', 'each', 'all', 'amount', "'m", 'nevertheless', 'move', 'although', 'via', 'else', 'due', 'meanwhile', 'latterly', 'during', 'another', 'ca', 'someone', 'becoming', 'unless', 'formerly', 'others', 'yours', 'many', 'should', 'him', 'their', 'wherein', 'serious', 'how', 'onto', 'have', 'several', 'under', 'sixty', 'well', 'twenty', 'together', 'from', 'once', 'indeed', 'after', "'ll", 'four', 'is', 'with', '‘ve', 'fifteen', 'which', 'becomes', 'such', 'herein', 're', 'just', 'ours', 'beyond', 'itself', 'more', "'d", 'therein', 'nothing', 'bottom', 'still', 'hence', 'whereafter', 'five', 'regarding', 'quite', 'them', 'toward', 'since', 'whereas', 'but', 'afterwards', 'would', 'the', 'himself', 'something', 'everything', 'everywhere', 'they', 'herself', 'top', 'whole', 'or', 'anything', 'give', 'often', 'thereby', 'what', 'too', 'a', 'however', 'thus', 'ten', 'whereby', 'neither', 'must', 'eight', 'name', 'then', 'were', 'its', 'became', 'yet', 'part', 'whose', '’s', 'cannot', 'fifty', 'noone', '’d', 'of', 'against', 'nor', 'down', 'using', 'out', 'whom', 'hereupon', 'even', 'doing', 'made', 'somehow', 'as', 'without', 'perhaps', 'used', 'below', 'do', 'whereupon', '’ve', 'and', 'has', 'last', 'your', 'it', 'whatever', 'both', 'above', 'behind', 'whence', 'make', 'any', 'be', 'various', 'enough', 'was', "'s", 'up', 'amongst', 'among', 'seeming', 'into', 'will', 'am', 'than', 'themselves', 'other', 'can', 'moreover', 'had', 'thereupon', 'yourselves', 'really', 'been', 'sometimes', 'forty', 'side', 'thru', 'almost', 'hereby', '‘s', 'see', 'rather', 'no', 'now', 'put', 'less', 'over', 'my', 'same'}

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %%
nlp.vocab['myself'].is_stop
# Out:
# True

# %%
nlp.vocab["fory"].is_stop
# Out:
# False

# %%
#to add a stop word
#add the word to set of stop words.use lowercase!
nlp.Defaults.stop_words.add('btw')

nlp.vocab['btw'].is_stop=True
